# %% [markdown]
# Decision Tree'lerin overfitting'e yatkın olduğunu söylemiştik. Bundan sakınmak için ensemble bir model olan Random Forest'ların kullanışlı olduğundan da bahsetmiştik. Bu seferki model tipi ise XGB, bu da random forest gibi çalışıyor. Fakat her seferinde oluşturulan modeli boost ederek yani geliştirerek ilerliyor.

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/150.0 MB ? eta -:--:--
#    ---------------------------------------- 1.3/150.0 MB 3.9 MB/s eta 0:00:38
#     --------------------------------------- 2.4/150.0 MB 4.6 MB/s eta 0:00:32
#     --------------------------------------- 3.7/150.0 MB 5.0 MB/s eta 0:00:30
#    - -------------------------------------- 4.7/150.0 MB 5.1 MB/s eta 0:00:29
#    - -------------------------------------- 6.0/150.0 MB 5.2 MB/s eta 0:00:28
#    - -------------------------------------- 7.1/150.0 MB 5.3 MB/s eta 0:00:28
#    -- ------------------------------------- 8.4/150.0 MB 5.3 MB/s eta 0:00:27
#    -- ------------------------------------- 9.4/150.0 MB 5.3 MB/s eta 0:00:27
#    -- ------------------------------------- 10.7/150.0 MB 5.4 MB/s eta 0:00:26
# ...

# %%
from IPython.display import display, Image
image_url = "https://miro.medium.com/v2/resize:fit:953/1*wpVgt07J_TeH3jEdc3A50g.png"
display(Image(url=image_url))
# Out:
# <img src="https://miro.medium.com/v2/resize:fit:953/1*wpVgt07J_TeH3jEdc3A50g.png"/>

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier # sklearn kütüphanesinin bir ürünü değil, göründüğü gibi

# %%
df = pd.read_csv('datasets/heart.csv')
df.head(3)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1

# %%
y = df['target']
x = df.drop('target',axis=1)

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.2, random_state = 18)

# %%
# decision tree ile deneme
dt = DecisionTreeClassifier()
model1 = dt.fit(x_train,y_train)
model1.score(x_test,y_test)
# Out:
# 0.8032786885245902

# %%
# random forest ile deneme
rf = RandomForestClassifier(n_estimators = 100)
model2 = rf.fit(x_train,y_train)
model2.score(x_test,y_test)
# Out:
# 0.8524590163934426

# %%
# xgboost ile deneme
xgb = XGBClassifier()
model3 = xgb.fit(x_train,y_train)
model3.score(x_test,y_test)
# Out:
# 0.8032786885245902
